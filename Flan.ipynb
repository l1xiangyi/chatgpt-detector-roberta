# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/csc3160
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/csc3160

# %% [markdown]
# # HunggingFace Flan

# %%
# %pip install sentencepiece transformers accelerate
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 17.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 101.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.1/219.1 kB 28.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 27.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 102.8 MB/s eta 0:00:00
# ...

# %%
from transformers import T5Tokenizer, T5ForConditionalGeneration

tokenizer = T5Tokenizer.from_pretrained("google/flan-t5-xxl")
model = T5ForConditionalGeneration.from_pretrained("google/flan-t5-xxl")

input_text = "translate English to German: How old are you?"
input_ids = tokenizer(input_text, return_tensors="pt").input_ids

outputs = model.generate(input_ids)
print(tokenizer.decode(outputs[0]))
# Out:
# ...
# Loading checkpoint shards:   0%|          | 0/5 [00:00<?, ?it/s]
# ...
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1346: UserWarning: Using `max_length`'s default (20) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# <pad> Wie alt sind Sie?</s>

# %%
import json

# Open the input file, output file and text file for storing Dolly's answers
with open('dataset/all.jsonl', 'r', encoding='utf-8') as jsonl_file, open('dataset/all_flan_from_1.jsonl', 'w', encoding='utf-8') as outfile, open('flan_from_1.txt', 'w', encoding='utf-8') as txtfile:
    for line in jsonl_file:
        # Parse JSONL line into a Python dictionary
        data = json.loads(line)
        
        # Extract the question
        question = data['question']
        print(question)
        input_text = question
        input_ids = tokenizer(input_text, return_tensors="pt").input_ids

        outputs = model.generate(input_ids)

        # Generate answer using Dolly model
        # res = generate_text(question)
        res = tokenizer.decode(outputs[0])
        print(res)

        # Add Dolly's answer to the data dictionary
        data['flan_answers'] = [res]
        
        # Write the modified data dictionary to the output file
        json.dump(data, outfile)
        outfile.write('\n')
        
        # Write Dolly's answer to the text file, replacing newline characters with spaces
        txtfile.write(res.replace('\n', ' ') + '\n')
# Out:
# Why is every book I hear about a " NY Times # 1 Best Seller " ? ELI5 : Why is every book I hear about a " NY Times # 1 Best Seller " ? Should n't there only be one " # 1 " best seller ? Please explain like I'm five.
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1346: UserWarning: Using `max_length`'s default (20) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# <pad> There are many books that are published every day.</s>
# If salt is so bad for cars , why do we use it on the roads ? As the title states , why do we use it ? is there no other option or what ? Please explain like I'm five.
# <pad> Salt is used to de-ice roads. It is bad for cars.</s>
# ...
